# %%
# install google search library
# !pip install google
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
# import google search
from googlesearch import search
# import regex
import re

# %%
df = pd.read_csv('fifa18_clean.csv')

# %%
df.head(10)
# Out:
#    Wage (€)  Value (€)               Name  Age  \
# 0    565000   95500000  Cristiano Ronaldo   32
# 1    565000  105000000           L. Messi   30
# 2    280000  123000000             Neymar   25
# 3    510000   97000000          L. Suárez   30
# 4    230000   61000000           M. Neuer   31
# 5    355000   92000000     R. Lewandowski   28
# 6    215000   64500000             De Gea   26
# 7    295000   90500000          E. Hazard   26
# 8    340000   79000000           T. Kroos   27
# 9    275000   77000000         G. Higuaín   29
#
#                                                Photo Nationality  \
# 0     https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1    https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2    https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.net/players/176/580/18_240.png     Uruguay
# 4    https://cdn.sofifa.org/48/18/players/167495.png     Germany
# ...

# %%
# find proper country names for nationalities
nat_list = ['Curacao', 'England', 'Northern Ireland', 'Scotland', 'Wales']

# %%
# create function to find enlish country names from geopy library
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="fifa22")
country_list = []

# %%
# function that gets latitude and longitude from country name list
def get_country(nat_list):
    for country in nat_list:
        location = geolocator.geocode(country)
        print (country, location.latitude, location.longitude)

# %%
# find country names from nationalities
def find_country(nat_list):
    for country in nat_list:
        try:
            location = geolocator.geocode(nat)
            country_list.append(location.address.split(',')[-1].strip())
            print (location.address.split(',')[-1].strip())
        except:
            country_list.append(nat)

# %%
get_country(nat_list)
# Out:
# Curacao 12.21339425 -69.0408499890865
# England 52.5310214 -1.2649062
# Northern Ireland 54.5859836 -6.9591554
# Scotland 56.7861112 -4.1140518
# Wales 52.2928116 -3.73893

# %%
# find country names
find_country(nat_list)
# Out:
# Nederland
# United Kingdom
# United Kingdom
# United Kingdom
# United Kingdom

# %%
# get list of columns
df.columns
# Out:
# Index(['Wage (€)', 'Value (€)', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Special', 'Acceleration',
#        'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
#        'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
#        'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
#        'GK reflexes', 'Heading accuracy', 'Interceptions', 'Jumping',
#        'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
#        'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
#        'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
#        'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB',
#        'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Preferred Positions',
#        'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
Acceleration
Agility
Balance
Ball control
Composure
Crossing
Curve
Dribbling
Finishing
Free kick accuracy
GK diving
GK handling
GK kicking
GK positioning
GK reflexes
Heading accuracy
Interceptions
Jumping
Long passing
Long shots
Marking
Penalties
Positioning
Reactions
Short passing
Shot power
Sliding tackle
Sprint speed
Stamina
Standing tackle
Strength
Vision
Volleys


'CAM'
'CB' 
'CDM'
'CF'
'CM'
'LAM'
'LB' 
'LCB'
'LCM'
'LDM'
'LF'
'LM'
'LS'
'LW'
'LWB'
'RAM'
'RB'
'RCB'
'RCM'
'RDM'
'RF'
'RM'
'RS'
'RW'
'RWB'
'ST'

# %%
# function that returns job openings for a specific keyword
